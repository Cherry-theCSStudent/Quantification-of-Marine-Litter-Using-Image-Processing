# %%
# !git clone https://github.com/soham96/trash_classifier.git
# Out:
# Cloning into 'trash_classifier'...
# remote: Enumerating objects: 49, done.
# remote: Total 49 (delta 0), reused 0 (delta 0), pack-reused 49
# Unpacking objects: 100% (49/49), done.

# %%
# !python mobilenet_training.py --nb_epoch 2 --batch_size 32 --model models/model1.h5
# Out:
# python3: can't open file 'mobilenet_training.py': [Errno 2] No such file or directory

# %%
cd trash_classifier/
# Out:
# /content/trash_classifier

# %%
# !python mobilenet_training.py --nb_epoch 2 --batch_size 32 --model models/model1.h5
# Out:
# Traceback (most recent call last):
#   File "mobilenet_training.py", line 3, in <module>
#     mpl.use('TkAgg')
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py", line 296, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py", line 358, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1281, in use
#     plt.switch_backend(name)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 237, in switch_backend
#     newbackend, required_framework, current_framework))
# ImportError: Cannot load backend 'TkAgg' which requires the 'tk' interactive framework, as 'headless' is currently running

# %%
# !python trash_classifier.py
# Out:
# 2021-01-23 12:22:20.026935: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "trash_classifier.py", line 2, in <module>
#     from pypylon import pylon
# ModuleNotFoundError: No module named 'pypylon'

# %%
# !pip install pypylon
# Out:
# ERROR: Could not find a version that satisfies the requirement pypylon (from versions: none)
# ERROR: No matching distribution found for pypylon

# %%
# !pip install pylon
# Out:
# ...
#      |████████████████████████████████| 788kB 9.4MB/s
# ...
#   Created wheel for pylon: filename=Pylon-0.4.4-cp36-none-any.whl size=506239 sha256=cc62a2a8f6cc8b68591b954e190f8960aaab398424173e57a2bfcc49f458d198
#   Stored in directory: /root/.cache/pip/wheels/06/12/68/06c19b99ea5af616087420823a3ef26900f556aa460e20586b
# Successfully built pylon
# ...

# %%
# !python trash_classifier.py
# Out:
# 2021-01-23 12:24:06.902047: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "trash_classifier.py", line 2, in <module>
#     from pypylon import pylon
# ModuleNotFoundError: No module named 'pypylon'
